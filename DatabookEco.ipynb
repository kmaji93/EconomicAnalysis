# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
df = pd.read_csv("Data.csv")
df.head(5)
# Out:
#    Years  Total_Population  Total_Revenue_Receipts  Net_Tax_Revenues  \
# 0   1991         888054875                   10.67              7.56
# 1   1992         906021106                   11.50              7.67
# 2   1993         924057817                   11.02              7.22
# 3   1994         942204249                    9.50              6.22
# 4   1995         960482795                   10.12              6.66
#
#    NonTax_Revenues  Recovery_of_Loans  PSU_investment  Total_Expenditure  \
# 0             2.11               1.00            0.00              18.52
# 1             2.44               0.92            0.47              17.06
# 2             2.68               0.85            0.26              16.38
# 3             2.56               0.72           -0.01              16.51
# 4             2.33               0.63            0.50              15.87
#
#    Interest  Defence  Subsidies  Plan_Expenditure  Other_Capital_Expenditure  \
# 0       3.8     2.71       2.14              4.99                        4.9
# 1       4.1     2.50       1.88              4.74                        3.9
# 2       4.2     2.35       1.45              4.90                        3.5
# 3       4.3     2.54       1.35              5.08                        3.3
# 4       4.4     2.30       1.17              4.68                        3.4
#
#    Fiscal_Deficit  GDP_Growth_Percentage  GDP_in_Billion  PerCap_Income
# 0            7.85               5.482396          288.21            317
# 1            5.56               4.750776          279.30            301
# 2            5.37               6.658924          327.28            346
# 3            7.01               7.574492          360.28            374
# 4            5.75               7.549522          392.90            400

# %%
df.notnull().sum()
# Out:
# Years                        26
# Total_Population             26
# Total_Revenue_Receipts       26
# Net_Tax_Revenues             26
# NonTax_Revenues              26
# Recovery_of_Loans            26
# PSU_investment               26
# Total_Expenditure            26
# Interest                     26
# Defence                      26
# Subsidies                    26
# Plan_Expenditure             26
# Other_Capital_Expenditure    26
# Fiscal_Deficit               26
# GDP_Growth_Percentage        26
# GDP_in_Billion               26
# PerCap_Income                26
# dtype: int64

# %%
df.describe()
# Out:
#              Years  Total_Population  Total_Revenue_Receipts  \
# count    26.000000      2.600000e+01               26.000000
# mean   2003.500000      1.113087e+09                9.900000
# std       7.648529      1.352482e+08                0.920622
# min    1991.000000      8.880549e+08                8.370000
# 25%    1997.250000      1.002047e+09                9.400000
# 50%    2003.500000      1.117082e+09                9.750000
# 75%    2009.750000      1.226803e+09               10.117500
# max    2016.000000      1.324171e+09               12.600000
#
#        Net_Tax_Revenues  NonTax_Revenues  Recovery_of_Loans  PSU_investment  \
# count         26.000000        26.000000          26.000000       26.000000
# mean           7.506538         2.251154           0.590769        0.243077
# std            0.586883         0.491629           0.579530        0.221662
# min            6.220000         1.360000           0.070000       -0.010000
# 25%            7.107500         1.827500           0.132500        0.045000
# 50%            7.480000         2.375000           0.550000        0.200000
# 75%            7.752500         2.655000           0.715000        0.447500
# max            8.810000         3.000000           2.400000        0.780000
#
#        Total_Expenditure   Interest    Defence  Subsidies  Plan_Expenditure  \
# count          26.000000  26.000000  26.000000  26.000000         26.000000
# mean           15.376154   3.931923   1.920769   1.633077          4.368846
# std             1.222915   0.565183   0.589908   0.443764          0.419813
# min            13.580000   3.040000   1.030000   1.070000          3.810000
# 25%            14.350000   3.415000   1.225000   1.300000          3.922500
# 50%            15.335000   4.010000   2.230000   1.410000          4.400000
# 75%            16.005000   4.375000   2.347500   2.027500          4.725000
# max            18.520000   4.800000   2.710000   2.560000          5.080000
#
#        Other_Capital_Expenditure  Fiscal_Deficit  GDP_Growth_Percentage  \
# count                  26.000000       26.000000              26.000000
# mean                    2.893462        5.263077               6.537749
# std                     0.976745        1.155747               1.687593
# min                     1.600000        2.540000               3.086698
# 25%                     1.807500        4.657500               5.295083
# 50%                     3.100000        5.385000               7.102806
# 75%                     3.500000        5.885000               7.907675
# max                     4.900000        7.850000               8.845756
#
#        GDP_in_Billion  PerCap_Income
# count       26.000000      26.000000
# mean      1058.454615     877.076923
# std        738.953467     530.567766
# min        279.300000     301.000000
# 25%        430.717500     421.750000
# 50%        764.765000     671.500000
# 75%       1786.192500    1422.500000
# max       2651.470000    1981.000000

# %%
plt.figure(figsize=(10,10))
sn.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
# ploting population graph
plt.figure(figsize=(20,10))
revenue = df['Total_Revenue_Receipts'].tolist()
year = df['Years'].tolist()
gdp = df['GDP_Growth_Percentage'].tolist()
plt.plot(year, revenue, linestyle = 'dashed')
plt.plot(year, gdp)
